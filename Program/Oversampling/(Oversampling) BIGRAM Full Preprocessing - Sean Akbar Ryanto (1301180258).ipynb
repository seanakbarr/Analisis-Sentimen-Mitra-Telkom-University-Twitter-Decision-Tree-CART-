# %% [markdown]
# Tugas Akhir :
#
# ### Analisis Sentimen Mitra untuk Telkom University Pada Media Sosial Twitter Menggunakan Algoritma Decision Tree (CART)
#
# Sean Akbar Ryanto (1301180258)

# %% [markdown]
# # Library Package

# %% [markdown]
# ## Install Library

# %%
# Library package untuk preprocessing stopwords removal dan stemming
# !pip install PySastrawi
# !pip install -U nltk
# !pip install googletrans==3.1.0a0
# !pip install matplotlib==3.4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: googletrans==3.1.0a0 in /usr/local/lib/python3.7/dist-packages (3.1.0a0)
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.7/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2022.6.15)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2022.7.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.7/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.7/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib==3.4 in /usr/local/lib/python3.7/dist-packages (3.4.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4) (7.1.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4) (1.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.4) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib==3.4) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib==3.4) (1.15.0)

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
import numpy as np
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string
import re
nltk.download('punkt')
nltk.download('stopwords')

from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

import matplotlib.pyplot as plt
import seaborn as sns 

from wordcloud import WordCloud, ImageColorGenerator
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Data Sentimen

# %% [markdown]
# ## Read Data

# %%
data = pd.read_csv('Dataset Internal Labelled.csv')
data
# Out:
#             Username                                         Text Tweet  \
# 0         telucareer  bersama kak Tasha Maric Tan.  Pada sharing kal...
# 1         telucareer  bekerja diperusahaan tersebut, yaitu kak Okta ...
# 2         telucareer  CTI Group adalah Perusahaan IT yang mendistrib...
# 3         telucareer  [Alumni Sharing Chapter Industry &amp; Campus ...
# 4         telucareer  CAE di tahun 2021, kamu tetap diperbolehkan me...
# ...              ...                                                ...
# 1847  infounivtelkom  Telkom University Badminton Club dengan Bangga...
# 1848  infounivtelkom  🛸[MAIN EVENT IFEST 2019]🛸 . Akhirnya yang ditu...
# 1849  infounivtelkom  #InfoEvent  [MAIN EVENT COMPFEST]  Halo, Ignit...
# 1850  infounivtelkom  #InfoEvent  [MANIFESTASI 2019 : R E T R O S P ...
# 1851  infounivtelkom  #InfoEvent  Hola, sobat Astro! 🚀✨ Salam Kreati...
#
#       Sentiment
# 0             1
# 1             0
# 2             0
# 3             1
# 4             1
# ...         ...
# 1847          0
# 1848          0
# 1849          0
# 1850          0
# 1851          0
#
# [1852 rows x 3 columns]

# %%
data['Sentiment'].replace(to_replace = -1, value = 'negatif', inplace=True)
data['Sentiment'].replace(to_replace = 0, value = 'netral', inplace=True)
data['Sentiment'].replace(to_replace = 1, value = 'positif', inplace=True)

data
# Out:
#             Username                                         Text Tweet  \
# 0         telucareer  bersama kak Tasha Maric Tan.  Pada sharing kal...
# 1         telucareer  bekerja diperusahaan tersebut, yaitu kak Okta ...
# 2         telucareer  CTI Group adalah Perusahaan IT yang mendistrib...
# 3         telucareer  [Alumni Sharing Chapter Industry &amp; Campus ...
# 4         telucareer  CAE di tahun 2021, kamu tetap diperbolehkan me...
# ...              ...                                                ...
# 1847  infounivtelkom  Telkom University Badminton Club dengan Bangga...
# 1848  infounivtelkom  🛸[MAIN EVENT IFEST 2019]🛸 . Akhirnya yang ditu...
# 1849  infounivtelkom  #InfoEvent  [MAIN EVENT COMPFEST]  Halo, Ignit...
# 1850  infounivtelkom  #InfoEvent  [MANIFESTASI 2019 : R E T R O S P ...
# 1851  infounivtelkom  #InfoEvent  Hola, sobat Astro! 🚀✨ Salam Kreati...
#
#      Sentiment
# 0      positif
# 1       netral
# 2       netral
# 3      positif
# 4      positif
# ...        ...
# 1847    netral
# 1848    netral
# 1849    netral
# 1850    netral
# 1851    netral
#
# [1852 rows x 3 columns]

# %%
# Menampilkan jumlah kategori sentimen yang dimiliki pada data
f , ax = plt.subplots(figsize = (6,5))
ax = sns.countplot(x='Sentiment', data=data)
ax.bar_label(ax.containers[0])
plt.title('Jumlah Kategori Sentimen', y=1, size=12)
plt.ylabel('Jumlah')
plt.xlabel('Sentimen')
# Out:
# Text(0.5, 0, 'Sentimen')

# %%
data['Sentiment'].value_counts()
# Out:
# netral     1156
# positif     457
# negatif     239
# Name: Sentiment, dtype: int64

# %%
# Menyalin data yang dimiliki kedalam variabel lain
sentimen1 = data.copy()

# %% [markdown]
# ## Translate Data

# %%
# from googletrans import Translator

# translator = Translator()

# %%
# sentimen1['Text Tweet'] = sentimen1['Text Tweet'].apply(translator.translate, src='en', dest='id')

# %%
# sentimen1['Text Tweet'] = sentimen1['Text Tweet'].apply(getattr, args=('text',))

# sentimen1

# %% [markdown]
# # Pre-Processing

# %% [markdown]
# ## Data Cleaning

# %%
# Fungsi untuk menghapus kata atau karakter unik
def remove_special(x):
    # remove tab, new line, ans back slice
    x = x.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    x = x.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    # x = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", " ",x).split())
    # remove number
    x = re.sub(r"\d+", "", x)
    # remove punctuation
    x = "".join([i for i in x if i not in string.punctuation])
    # remove single char
    # x = re.sub(r"\b[a-zA-Z]\b", "", x)
    # remove incomplete URL
    # x = x.replace("http://", " ").replace("https://", " ")
    # remove whitespace
    x = x.strip()
    return x

# Menghapus kata/karakter unik pada data yang dimiliki
sentimen1['Text Tweet'] = sentimen1['Text Tweet'].apply(lambda x:remove_special(x))

sentimen1
# Out:
#             Username                                         Text Tweet  \
# 0         telucareer  bersama kak Tasha Maric Tan  Pada sharing kali...
# 1         telucareer  bekerja diperusahaan tersebut yaitu kak Okta P...
# 2         telucareer  CTI Group adalah Perusahaan IT yang mendistrib...
# 3         telucareer  Alumni Sharing Chapter Industry amp Campus Hir...
# 4         telucareer  CAE di tahun  kamu tetap diperbolehkan mendaft...
# ...              ...                                                ...
# 1847  infounivtelkom  Telkom University Badminton Club dengan Bangga...
# 1848  infounivtelkom  MAIN EVENT IFEST   Akhirnya yang ditunggutungg...
# 1849  infounivtelkom  InfoEvent  MAIN EVENT COMPFEST  Halo Igniters ...
# 1850  infounivtelkom  InfoEvent  MANIFESTASI   R E T R O S P E C T I...
# 1851  infounivtelkom  InfoEvent  Hola sobat Astro  Salam Kreatifitas...
#
#      Sentiment
# 0      positif
# 1       netral
# 2       netral
# 3      positif
# 4      positif
# ...        ...
# 1847    netral
# 1848    netral
# 1849    netral
# 1850    netral
# 1851    netral
#
# [1852 rows x 3 columns]

# %% [markdown]
# ## Case Folding

# %%
# Mengubah seluruh teks menjadi huruf kecil
sentimen1['Text Tweet'] = sentimen1['Text Tweet'].str.lower()

sentimen1
# Out:
#             Username                                         Text Tweet  \
# 0         telucareer  bersama kak tasha maric tan  pada sharing kali...
# 1         telucareer  bekerja diperusahaan tersebut yaitu kak okta p...
# 2         telucareer  cti group adalah perusahaan it yang mendistrib...
# 3         telucareer  alumni sharing chapter industry amp campus hir...
# 4         telucareer  cae di tahun  kamu tetap diperbolehkan mendaft...
# ...              ...                                                ...
# 1847  infounivtelkom  telkom university badminton club dengan bangga...
# 1848  infounivtelkom  main event ifest   akhirnya yang ditunggutungg...
# 1849  infounivtelkom  infoevent  main event compfest  halo igniters ...
# 1850  infounivtelkom  infoevent  manifestasi   r e t r o s p e c t i...
# 1851  infounivtelkom  infoevent  hola sobat astro  salam kreatifitas...
#
#      Sentiment
# 0      positif
# 1       netral
# 2       netral
# 3      positif
# 4      positif
# ...        ...
# 1847    netral
# 1848    netral
# 1849    netral
# 1850    netral
# 1851    netral
#
# [1852 rows x 3 columns]

# %% [markdown]
# ## Remove Emoji

# %%
# def deEmojify(text):
#     regrex_pattern = re.compile(pattern = "["
#         u"\U0001F600-\U0001F64F"  # emoticons
#         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
#         u"\U0001F680-\U0001F6FF"  # transport & map symbols
#         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
#                            "]+", flags = re.UNICODE)
#     return regrex_pattern.sub(r'',text)

# sentimen1['Text Tweet'] = sentimen1['Text Tweet'].apply(deEmojify)

# sentimen1

# %% [markdown]
# ## Tokenization

# %%
# Fungsi untuk memecah kalimat pada dataframe menjadi per kata tiap barisnya
def word_tokenized(x):
  return word_tokenize(x)

# Menginisialisasikan fungsi tokenisasi yang telah dibuat ke data
sentimen1['Text Tweet']= sentimen1['Text Tweet'].apply(word_tokenized)

sentimen1
# Out:
#             Username                                         Text Tweet  \
# 0         telucareer  [bersama, kak, tasha, maric, tan, pada, sharin...
# 1         telucareer  [bekerja, diperusahaan, tersebut, yaitu, kak, ...
# 2         telucareer  [cti, group, adalah, perusahaan, it, yang, men...
# 3         telucareer  [alumni, sharing, chapter, industry, amp, camp...
# 4         telucareer  [cae, di, tahun, kamu, tetap, diperbolehkan, m...
# ...              ...                                                ...
# 1847  infounivtelkom  [telkom, university, badminton, club, dengan, ...
# 1848  infounivtelkom  [main, event, ifest, akhirnya, yang, ditunggut...
# 1849  infounivtelkom  [infoevent, main, event, compfest, halo, ignit...
# 1850  infounivtelkom  [infoevent, manifestasi, r, e, t, r, o, s, p, ...
# 1851  infounivtelkom  [infoevent, hola, sobat, astro, salam, kreatif...
#
#      Sentiment
# 0      positif
# 1       netral
# 2       netral
# 3      positif
# 4      positif
# ...        ...
# 1847    netral
# 1848    netral
# 1849    netral
# 1850    netral
# 1851    netral
#
# [1852 rows x 3 columns]

# %% [markdown]
# ## Normalisasi

# %%
# Download data KBBI untuk normalisasi
# !wget 'https://drive.google.com/uc?export=download&id=1pdvzHGWmnRci3FSWnzF30xMLhG1R8GnG' -O kbba.txt
# !wget 'https://drive.google.com/uc?export=download&id=14M_Vi-ySjezLMXgFGThjWxerSixowes_' -O kbba_extend.txt
# Out:
# --2022-07-15 07:39:49--  https://drive.google.com/uc?export=download&id=1pdvzHGWmnRci3FSWnzF30xMLhG1R8GnG
# Resolving drive.google.com (drive.google.com)... 172.253.122.139, 172.253.122.113, 172.253.122.102, ...
# Connecting to drive.google.com (drive.google.com)|172.253.122.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-14-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/lmbi92ih7osjss9l5b7984t78mmakii7/1657870725000/00150260977202157621/*/1pdvzHGWmnRci3FSWnzF30xMLhG1R8GnG?e=download&uuid=bf2caf65-a015-48be-a65f-e90ab73957b8 [following]
# Warning: wildcards not supported in HTTP.
# --2022-07-15 07:39:50--  https://doc-0s-14-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/lmbi92ih7osjss9l5b7984t78mmakii7/1657870725000/00150260977202157621/*/1pdvzHGWmnRci3FSWnzF30xMLhG1R8GnG?e=download&uuid=bf2caf65-a015-48be-a65f-e90ab73957b8
# Resolving doc-0s-14-docs.googleusercontent.com (doc-0s-14-docs.googleusercontent.com)... 142.250.188.193, 2607:f8b0:4004:836::2001
# Connecting to doc-0s-14-docs.googleusercontent.com (doc-0s-14-docs.googleusercontent.com)|142.250.188.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20753 (20K) [text/plain]
# Saving to: ‘kbba.txt’
#
# kbba.txt            100%[===================>]  20.27K  --.-KB/s    in 0s
#
# 2022-07-15 07:39:50 (91.4 MB/s) - ‘kbba.txt’ saved [20753/20753]
#
# --2022-07-15 07:39:50--  https://drive.google.com/uc?export=download&id=14M_Vi-ySjezLMXgFGThjWxerSixowes_
# Resolving drive.google.com (drive.google.com)... 172.253.122.100, 172.253.122.102, 172.253.122.138, ...
# Connecting to drive.google.com (drive.google.com)|172.253.122.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-14-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/kbeo0eulogi53enj3n9fvgivbpb9692f/1657870725000/00150260977202157621/*/14M_Vi-ySjezLMXgFGThjWxerSixowes_?e=download&uuid=8ec37a94-4748-4932-8ca8-f749655464ab [following]
# Warning: wildcards not supported in HTTP.
# --2022-07-15 07:39:51--  https://doc-0s-14-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/kbeo0eulogi53enj3n9fvgivbpb9692f/1657870725000/00150260977202157621/*/14M_Vi-ySjezLMXgFGThjWxerSixowes_?e=download&uuid=8ec37a94-4748-4932-8ca8-f749655464ab
# Resolving doc-0s-14-docs.googleusercontent.com (doc-0s-14-docs.googleusercontent.com)... 142.250.188.193, 2607:f8b0:4004:836::2001
# Connecting to doc-0s-14-docs.googleusercontent.com (doc-0s-14-docs.googleusercontent.com)|142.250.188.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 260421 (254K) [text/plain]
# Saving to: ‘kbba_extend.txt’
#
# kbba_extend.txt     100%[===================>] 254.32K  --.-KB/s    in 0.002s
#
# 2022-07-15 07:39:51 (151 MB/s) - ‘kbba_extend.txt’ saved [260421/260421]

# %%
normalized_word = pd.read_csv("new_kamusalay.csv", encoding='latin-1')

normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

sentimen1['Text Tweet'] = sentimen1['Text Tweet'].apply(normalized_term)

sentimen1
# Out:
#             Username                                         Text Tweet  \
# 0         telucareer  [bersama, kak, tasha, maric, tan, pada, sharin...
# 1         telucareer  [bekerja, diperusahaan, tersebut, yaitu, kak, ...
# 2         telucareer  [cti, grup, adalah, perusahaan, it, yang, mend...
# 3         telucareer  [alumni, sharing, chapter, industri, amp, kamp...
# 4         telucareer  [cae, di, tahun, kamu, tetap, diperbolehkan, m...
# ...              ...                                                ...
# 1847  infounivtelkom  [telkom, universitas, badminton, club, dengan,...
# 1848  infounivtelkom  [main, acara, ifest, akhirnya, yang, ditunggut...
# 1849  infounivtelkom  [infoevent, main, acara, compfest, halo, ignit...
# 1850  infounivtelkom  [infoevent, manifestasi, r, e, t, r, o, si, p,...
# 1851  infounivtelkom  [infoevent, hola, sobat, astro, salam, kreativ...
#
#      Sentiment
# 0      positif
# 1       netral
# 2       netral
# 3      positif
# 4      positif
# ...        ...
# 1847    netral
# 1848    netral
# 1849    netral
# 1850    netral
# 1851    netral
#
# [1852 rows x 3 columns]

# %% [markdown]
# ## Stopword Removal

# %%
# Download daftar stopwords tambahan
# !wget 'https://drive.google.com/uc?export=download&id=10N-yYkDUReG53SXJrghX1kcJs2_fiB3P' -O stop_new2.txt
# Out:
# --2022-07-15 07:39:52--  https://drive.google.com/uc?export=download&id=10N-yYkDUReG53SXJrghX1kcJs2_fiB3P
# Resolving drive.google.com (drive.google.com)... 172.253.122.138, 172.253.122.102, 172.253.122.100, ...
# Connecting to drive.google.com (drive.google.com)|172.253.122.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-14-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/f2jf9vk16ipn8nc6mcl8jrnrm8guqakg/1657870725000/00150260977202157621/*/10N-yYkDUReG53SXJrghX1kcJs2_fiB3P?e=download&uuid=6c870960-f7ca-4f2c-bf9a-091e573e8793 [following]
# Warning: wildcards not supported in HTTP.
# --2022-07-15 07:39:53--  https://doc-04-14-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/f2jf9vk16ipn8nc6mcl8jrnrm8guqakg/1657870725000/00150260977202157621/*/10N-yYkDUReG53SXJrghX1kcJs2_fiB3P?e=download&uuid=6c870960-f7ca-4f2c-bf9a-091e573e8793
# Resolving doc-04-14-docs.googleusercontent.com (doc-04-14-docs.googleusercontent.com)... 142.250.188.193, 2607:f8b0:4004:836::2001
# Connecting to doc-04-14-docs.googleusercontent.com (doc-04-14-docs.googleusercontent.com)|142.250.188.193|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17691 (17K) [text/plain]
# Saving to: ‘stop_new2.txt’
#
# stop_new2.txt       100%[===================>]  17.28K  --.-KB/s    in 0s
#
# 2022-07-15 07:39:53 (70.2 MB/s) - ‘stop_new2.txt’ saved [17691/17691]

# %%
# Menginisialisasikan Sastrawi
factory = StopWordRemoverFactory()
list_stopwords = factory.get_stop_words()
list_stopwords2 = stopwords.words('indonesian')

# Menambahkan data stopwords
list_stopwords.extend(['kak', 'gwa', 'ayo', 'banget', 'indonesia','indihome', 
                       'pas', 'iya', 'ya', 'sih', 'deh', 'loh', 
                       'oiya','nih', 'ok', 'ah','gua','lg',
                       "yg", "dg", "rt", "dgn", "ny", "d", 'klo', 'ucl','kali'
                       'kalo', 'amp', 'biar', 'bikin', 'bilang','mlu','gni' 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 'by'
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't','ca', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah','ke','di','ini','mah'])

txt_stopword = pd.read_csv('stopword.csv', names= ["stopwords"], header = None)

list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

list_stopwords = set(list_stopwords)

# Fungsi untuk menghapus kata yang tidak diperlukan
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

def stopwords_removal2(words):
    return [word for word in words if word not in list_stopwords2]

# Menginisialisasikan fungsi stopwords_removal yang telah dibuat ke data yang dimiliki
sentimen1['Text Tweet'] = sentimen1['Text Tweet'].apply(stopwords_removal)
sentimen1['Text Tweet'] = sentimen1['Text Tweet'].apply(stopwords_removal2)

sentimen1
# Out:
#             Username                                         Text Tweet  \
# 0         telucareer  [tasha, maric, tan, sharing, informasi, lengka...
# 1         telucareer  [diperusahaan, okta, puspita, tim, leader, of,...
# 2         telucareer  [cti, grup, perusahaan, it, mendistribusikan, ...
# 3         telucareer  [alumni, sharing, chapter, industri, kampus, h...
# 4         telucareer  [cae, diperbolehkan, mendaftar, mendaftar, dih...
# ...              ...                                                ...
# 1847  infounivtelkom  [telkom, universitas, badminton, club, bangga,...
# 1848  infounivtelkom  [main, acara, ifest, ditunggutunggu, yuk, ajak...
# 1849  infounivtelkom  [infoevent, main, acara, compfest, igniters, p...
# 1850  infounivtelkom  [infoevent, manifestasi, si, finally, the, wev...
# 1851  infounivtelkom  [infoevent, hola, sobat, astro, kreativitas, b...
#
#      Sentiment
# 0      positif
# 1       netral
# 2       netral
# 3      positif
# 4      positif
# ...        ...
# 1847    netral
# 1848    netral
# 1849    netral
# 1850    netral
# 1851    netral
#
# [1852 rows x 3 columns]

# %% [markdown]
# ## Stemming

# %%
# Menginisialisasikan Sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Mengubah seluruh kata pada dataframe menjadi kata dasar
sentimen1['Text Tweet'] = sentimen1['Text Tweet'].apply(lambda x: [stemmer.stem(y) for y in x])

sentimen1
# Out:
#             Username                                         Text Tweet  \
# 0         telucareer  [tasha, maric, tan, sharing, informasi, lengka...
# 1         telucareer  [usaha, okta, puspita, tim, leader, of, techni...
# 2         telucareer  [cti, grup, usaha, it, distribusi, merek, tekn...
# 3         telucareer  [alumni, sharing, chapter, industri, kampus, h...
# 4         telucareer  [cae, boleh, daftar, daftar, hubung, admin, pe...
# ...              ...                                                ...
# 1847  infounivtelkom  [telkom, universitas, badminton, club, bangga,...
# 1848  infounivtelkom  [main, acara, ifest, ditunggutunggu, yuk, ajak...
# 1849  infounivtelkom  [infoevent, main, acara, compfest, igniters, p...
# 1850  infounivtelkom  [infoevent, manifestasi, si, finally, the, wev...
# 1851  infounivtelkom  [infoevent, hola, sobat, astro, kreativitas, b...
#
#      Sentiment
# 0      positif
# 1       netral
# 2       netral
# 3      positif
# 4      positif
# ...        ...
# 1847    netral
# 1848    netral
# 1849    netral
# 1850    netral
# 1851    netral
#
# [1852 rows x 3 columns]

# %% [markdown]
# ## Untokenization

# %%
#Menggabungkan kembali kata kata yang telah dipecah menjadi 1 kalimat
def untokenize(words):
    text = ' '.join(words)
    step1 = text.replace("`` ", '"').replace(" ''", '"').replace('. . .',  '...')
    step2 = step1.replace(" ( ", " (").replace(" ) ", ") ")
    step3 = re.sub(r' ([.,:;?!%]+)([ \'"`])', r"\1\2", step2)
    step4 = re.sub(r' ([.,:;?!%]+)$', r"\1", step3)
    step5 = step4.replace(" '", "'").replace(" n't", "n't").replace(
         "can not", "cannot")
    step6 = step5.replace(" ` ", " '")
    return step6.strip()

sentimen1['Text Tweet'] = sentimen1['Text Tweet'].apply(untokenize)

sentimen1
# Out:
#             Username                                         Text Tweet  \
# 0         telucareer  tasha maric tan sharing informasi lengkap lowo...
# 1         telucareer  usaha okta puspita tim leader of technical net...
# 2         telucareer  cti grup usaha it distribusi merek teknologi i...
# 3         telucareer  alumni sharing chapter industri kampus hiring ...
# 4         telucareer  cae boleh daftar daftar hubung admin perihal j...
# ...              ...                                                ...
# 1847  infounivtelkom  telkom universitas badminton club bangga semba...
# 1848  infounivtelkom  main acara ifest ditunggutunggu yuk ajak teman...
# 1849  infounivtelkom  infoevent main acara compfest igniters pasti h...
# 1850  infounivtelkom  infoevent manifestasi si finally the weve been...
# 1851  infounivtelkom  infoevent hola sobat astro kreativitas batas t...
#
#      Sentiment
# 0      positif
# 1       netral
# 2       netral
# 3      positif
# 4      positif
# ...        ...
# 1847    netral
# 1848    netral
# 1849    netral
# 1850    netral
# 1851    netral
#
# [1852 rows x 3 columns]

# %%
# Start with one review:
all_data = pd.DataFrame(' '.join(sentimen1['Text Tweet'].tolist()), columns=['Text Tweet'], index=[0])
text = all_data['Text Tweet'][0]

# Create and generate a word cloud image:
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# Display the generated image:
plt.figure(figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Oversampling

# %%
x_imb = sentimen1['Text Tweet']
y_imb = sentimen1['Sentiment']

# %%
x_imb = x_imb.values.reshape(-1, 1)

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

ros = RandomOverSampler(sampling_strategy='minority')
x_os, y_os = ros.fit_resample(x_imb, y_imb)
x_os, y_os = ros.fit_resample(x_os, y_os)

# %%
Counter(y_os)
# Out:
# Counter({'negatif': 1156, 'netral': 1156, 'positif': 1156})

# %%
# Menampilkan jumlah kategori sentimen yang dimiliki pada data
f , ax = plt.subplots(figsize = (6,5))
ax = sns.countplot(x=y_os, data=sentimen1)
ax.bar_label(ax.containers[0])
plt.title('Jumlah Kategori Sentimen', y=1, size=12)
plt.ylabel('Jumlah')
plt.xlabel('Sentimen')
# Out:
# Text(0.5, 0, 'Sentimen')

# %% [markdown]
# # Data Splitting

# %%
# Memecah/memisahkan dataset kedalam bentuk data train dan data validasi dengan perbandingan 80:20
x1 = x_os.flatten()
y1 = y_os

from sklearn.model_selection import train_test_split

x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.20 , shuffle=True, random_state=123)

# %%
# Memecah/memisahkan dataset kedalam bentuk data train dan data validasi dengan perbandingan 75:25
x2 = x_os.flatten()
y2 = y_os

from sklearn.model_selection import train_test_split

x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, test_size=0.25 , shuffle=True, random_state=123)

# %%
# Memecah/memisahkan dataset kedalam bentuk data train dan data validasi dengan perbandingan 70:30
x3 = x_os.flatten()
y3 = y_os

from sklearn.model_selection import train_test_split

x3_train, x3_test, y3_train, y3_test = train_test_split(x3, y3, test_size=0.30 , shuffle=True, random_state=123)

# %% [markdown]
# # Feature Extraction TF-IDF (80:20)

# %% [markdown]
# ## Proses Pembobotan TF-IDF

# %%
# Melakukan pembobotan terhadap data x_train dan y_train yang telah dilakukan splitting
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(ngram_range=(2,2))
vector = vectorizer.fit(sentimen1['Text Tweet'])
x1_train_tfidf = vector.transform(x1_train.astype(str))
x1_test_tfidf = vector.transform(x1_test)

# %% [markdown]
# ## Hasil Pembobotan TF-IDF

# %%
# Tabel Hasil Pembobotan x_train
weights = np.asarray(x1_train_tfidf.mean(axis=0)).ravel().tolist()
weights_x1_train_tfidf = pd.DataFrame({"term": vector.get_feature_names(),"weight": weights})
weights_x1_train_tfidf.sort_values(by= "weight", ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                                             term    weight
# 15198                   telucae telkomuniversity  0.039549
# 8892                lowongankerjajakarta telucae  0.027084
# 8826                                lowong kerja  0.025745
# 6598                          internship jobfair  0.025323
# 8881   lowongankerjabandung lowongankerjajakarta  0.023114
# ...                                          ...       ...
# 6875                              jakarta please  0.000000
# 15554                             tenang steroid  0.000000
# 11780                             programmer tpp  0.000000
# 1886                              bisnis startup  0.000000
# 7463                                 karier tech  0.000000
#
# [17221 rows x 2 columns]

# %%
# Tabel Hasil Pembobotan x_test
weights = np.asarray(x1_test_tfidf.mean(axis=0)).ravel().tolist()
weights_x1_test_tfidf = pd.DataFrame({"term": vector.get_feature_names(),"weight": weights})
weights_x1_test_tfidf.sort_values(by= "weight", ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                                term    weight
# 15198      telucae telkomuniversity  0.040949
# 6598             internship jobfair  0.028287
# 8892   lowongankerjajakarta telucae  0.027610
# 8826                   lowong kerja  0.026419
# 7085   jobfair lowongankerjabandung  0.023523
# ...                             ...       ...
# 6838                     jaga sehat  0.000000
# 6842               jagaditha posisi  0.000000
# 6843                       jago app  0.000000
# 6844           jaisyurrahman beliau  0.000000
# 8610           link httpstcodrxtctf  0.000000
#
# [17221 rows x 2 columns]

# %% [markdown]
# # Feature Extraction TF-IDF (75:25)

# %% [markdown]
# ## Proses Pembobotan TF-IDF

# %%
# Melakukan pembobotan terhadap data x_train dan y_train yang telah dilakukan splitting
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(ngram_range=(2,2))
vector = vectorizer.fit(sentimen1['Text Tweet'])
x2_train_tfidf = vector.transform(x2_train.astype(str))
x2_test_tfidf = vector.transform(x2_test)

# %% [markdown]
# ## Hasil Pembobotan TF-IDF

# %%
# Tabel Hasil Pembobotan x_train
weights = np.asarray(x2_train_tfidf.mean(axis=0)).ravel().tolist()
weights_x2_train_tfidf = pd.DataFrame({"term": vector.get_feature_names(),"weight": weights})
weights_x2_train_tfidf.sort_values(by= "weight", ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                                             term    weight
# 15198                   telucae telkomuniversity  0.038922
# 8892                lowongankerjajakarta telucae  0.026714
# 8826                                lowong kerja  0.025930
# 6598                          internship jobfair  0.025613
# 8881   lowongankerjabandung lowongankerjajakarta  0.023160
# ...                                          ...       ...
# 7007                                  jawab buka  0.000000
# 14511                        systems development  0.000000
# 9940                                     nah loh  0.000000
# 7914                        kompetensi wawancara  0.000000
# 4529                                 finally the  0.000000
#
# [17221 rows x 2 columns]

# %%
# Tabel Hasil Pembobotan x_test
weights = np.asarray(x2_test_tfidf.mean(axis=0)).ravel().tolist()
weights_x2_test_tfidf = pd.DataFrame({"term": vector.get_feature_names(),"weight": weights})
weights_x2_test_tfidf.sort_values(by= "weight", ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                                             term    weight
# 15198                   telucae telkomuniversity  0.042550
# 8892                lowongankerjajakarta telucae  0.028615
# 6598                          internship jobfair  0.026826
# 8826                                lowong kerja  0.025729
# 8881   lowongankerjabandung lowongankerjajakarta  0.022641
# ...                                          ...       ...
# 7114                               join ekslusif  0.000000
# 7117                                join paragon  0.000000
# 7118                            join recruitment  0.000000
# 7120                                   join telu  0.000000
# 8610                        link httpstcodrxtctf  0.000000
#
# [17221 rows x 2 columns]

# %% [markdown]
# # Feature Extraction TF-IDF (70:30)

# %% [markdown]
# ## Proses Pembobotan TF-IDF

# %%
# Melakukan pembobotan terhadap data x_train dan y_train yang telah dilakukan splitting
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(ngram_range=(2,2))
vector = vectorizer.fit(sentimen1['Text Tweet'])
x3_train_tfidf = vector.transform(x3_train.astype(str))
x3_test_tfidf = vector.transform(x3_test)

# %% [markdown]
# ## Hasil Pembobotan TF-IDF

# %%
# Tabel Hasil Pembobotan x_train
weights = np.asarray(x3_train_tfidf.mean(axis=0)).ravel().tolist()
weights_x3_train_tfidf = pd.DataFrame({"term": vector.get_feature_names(),"weight": weights})
weights_x3_train_tfidf.sort_values(by= "weight", ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                                             term    weight
# 15198                   telucae telkomuniversity  0.039482
# 8892                lowongankerjajakarta telucae  0.027148
# 8826                                lowong kerja  0.026476
# 6598                          internship jobfair  0.025780
# 8881   lowongankerjabandung lowongankerjajakarta  0.023339
# ...                                          ...       ...
# 6149                           industri dkatalis  0.000000
# 6154                                industri has  0.000000
# 6161                              industri lulus  0.000000
# 6163                                 industri mk  0.000000
# 8610                        link httpstcodrxtctf  0.000000
#
# [17221 rows x 2 columns]

# %%
# Tabel Hasil Pembobotan x_test
weights = np.asarray(x3_test_tfidf.mean(axis=0)).ravel().tolist()
weights_x3_test_tfidf = pd.DataFrame({"term": vector.get_feature_names(),"weight": weights})
weights_x3_test_tfidf.sort_values(by= "weight", ascending = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#                                             term    weight
# 15198                   telucae telkomuniversity  0.040639
# 8892                lowongankerjajakarta telucae  0.027286
# 6598                          internship jobfair  0.026234
# 8826                                lowong kerja  0.024488
# 8881   lowongankerjabandung lowongankerjajakarta  0.022311
# ...                                          ...       ...
# 9672                                    min alam  0.000000
# 9673                                min aplikasi  0.000000
# 9674                                  min bidang  0.000000
# 9675                                 min diploma  0.000000
# 0                         abadi httpstcocwnlxmbj  0.000000
#
# [17221 rows x 2 columns]

# %% [markdown]
# # Klasifikasi

# %%
# Library package untuk evaluasi model dengan nilai akurasi
from sklearn.metrics import accuracy_score

# Library package untuk evaluasi keseluruhan performa model
from sklearn.metrics import classification_report

# %% [markdown]
# ## Hyperparameter Tuning GridSearchCV (80:20)

# %%
from sklearn.tree import DecisionTreeClassifier     # Library package untuk klasifikasi algoritma Decision Tree
from sklearn.model_selection import GridSearchCV    # Library package untuk menggunakan validasi GridSearchCV

# Mencari parameter max_depth terbaik antara 1 sampai 30 untuk Decision Tree (CART)
param_grid = {'max_depth' : np.arange(1, 30),
              'splitter' : ['best', 'random']}

# Melatih model untuk mencari parameter max_dept terbaik untuk Decision Tree (CART) berdasarkan nilai akurasi
dt_clf1 = GridSearchCV(DecisionTreeClassifier(criterion='gini'), param_grid, cv=10, scoring='accuracy')
dt_clf1.fit(x1_train_tfidf, y1_train)

# Menampilkan parameter max_depth terbaik
print('best parameter : ', dt_clf1.best_params_)
# Out:
# best parameter :  {'max_depth': 28, 'splitter': 'random'}

# %%
# Menampilkan akurasi terbaik
print('accuracy : ', dt_clf1.best_score_)
# Out:
# accuracy :  0.7065955899540295

# %% [markdown]
# ### Decision Tree 80:20

# %%
# Melatih model klasifikasi dengan algoritma Decision Tree (CART)
dt_clf1 = DecisionTreeClassifier(criterion='gini', splitter='random', max_depth=28)
dt_clf1.fit(x1_train_tfidf, y1_train)

# Memprediksi label sentimen dengan data validasi
dt_predict1 = dt_clf1.predict(x1_test_tfidf)

# Menampilkan akurasi dari algoritma Decision Tree (CART) yang didapatkan
print("Decision Tree Accuracy Score:", round(accuracy_score(dt_predict1, y1_test) * 100, 4), '%')

# Menampilkan hasil evaluasi performa secara keseluruhan
print("Classification Report:")
print(classification_report(dt_predict1, y1_test, digits=4))
# Out:
# Decision Tree Accuracy Score: 70.4611 %
# Classification Report:
#               precision    recall  f1-score   support
#
#      negatif     0.7956    0.9676    0.8732       185
#       netral     0.3361    0.9877    0.5016        81
#      positif     0.9957    0.5374    0.6980       428
#
#     accuracy                         0.7046       694
#    macro avg     0.7091    0.8309    0.6909       694
# weighted avg     0.8653    0.7046    0.7218       694

# %% [markdown]
# ## Confusion Matrix 80:20

# %%
from sklearn.metrics import confusion_matrix

f , ax = plt.subplots(figsize = (6,5))
conf_mat = confusion_matrix(y1_test, dt_predict1)
class_label = ["Negatif", "Netral", "Positif"]
cm = pd.DataFrame(conf_mat, index=class_label, columns=class_label)
sns.heatmap(cm, annot = True,  fmt=".0f", ax=ax)
plt.title("Confusion Matrix Decision Tree 80:20", y=1, size=12)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# ## Hyperparameter Tuning GridSearchCV (75:25)

# %%
from sklearn.tree import DecisionTreeClassifier     # Library package untuk klasifikasi algoritma Decision Tree
from sklearn.model_selection import GridSearchCV

# Mencari parameter max_depth terbaik antara 1 sampai 30 untuk Decision Tree (CART)
param_grid = {'max_depth' : np.arange(1, 30),
              'splitter' : ['best', 'random']}

# Melatih model untuk mencari parameter max_dept terbaik untuk Decision Tree (CART) berdasarkan nilai akurasi
dt_clf2 = GridSearchCV(DecisionTreeClassifier(criterion='gini'), param_grid, cv=10, scoring='accuracy')
dt_clf2.fit(x2_train_tfidf, y2_train)

# Menampilkan parameter max_depth terbaik
print('best parameter : ', dt_clf2.best_params_)
# Out:
# best parameter :  {'max_depth': 29, 'splitter': 'random'}

# %%
# Menampilkan akurasi terbaik
print('accuracy : ', dt_clf2.best_score_)
# Out:
# accuracy :  0.7124329501915709

# %% [markdown]
# ### Decision Tree 75:25

# %%
# Melatih model klasifikasi dengan algoritma Decision Tree (CART)
dt_clf2 = DecisionTreeClassifier(criterion='gini', splitter='random', max_depth=29)
dt_clf2.fit(x2_train_tfidf, y2_train)

# Memprediksi label sentimen dengan data validasi
dt_predict2 = dt_clf2.predict(x2_test_tfidf)

# Menampilkan akurasi dari algoritma Decision Tree (CART) yang didapatkan
print("Decision Tree Accuracy Score:", round(accuracy_score(dt_predict2, y2_test) * 100, 4), '%')

# Menampilkan hasil evaluasi performa secara keseluruhan
print("Classification Report:")
print(classification_report(dt_predict2, y2_test, digits=4))
# Out:
# Decision Tree Accuracy Score: 70.7036 %
# Classification Report:
#               precision    recall  f1-score   support
#
#      negatif     0.7921    0.9485    0.8633       233
#       netral     0.3792    0.9187    0.5368       123
#      positif     0.9621    0.5460    0.6966       511
#
#     accuracy                         0.7070       867
#    macro avg     0.7111    0.8044    0.6989       867
# weighted avg     0.8337    0.7070    0.7187       867

# %% [markdown]
# ## Confusion Matrix Decision Tree 75:25

# %%
from sklearn.metrics import confusion_matrix

f , ax = plt.subplots(figsize = (6,5))
conf_mat = confusion_matrix(y2_test, dt_predict2)
class_label = ["Negatif", "Netral", "Positif"]
cm = pd.DataFrame(conf_mat, index=class_label, columns=class_label)
sns.heatmap(cm, annot = True,  fmt=".0f", ax=ax)
plt.title("Confusion Matrix Decision Tree 75:25", y=1, size=12)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# ## Hyperparameter Tuning GridSearchCV (70:30)

# %%
from sklearn.tree import DecisionTreeClassifier     # Library package untuk klasifikasi algoritma Decision Tree
from sklearn.model_selection import GridSearchCV

# Mencari parameter max_depth terbaik antara 1 sampai 30 untuk Decision Tree (CART)
param_grid = {'max_depth' : np.arange(1, 30),
              'splitter' : ['best', 'random']}

# Melatih model untuk mencari parameter max_dept terbaik untuk Decision Tree (CART) berdasarkan nilai akurasi
dt_clf3 = GridSearchCV(DecisionTreeClassifier(criterion='gini'), param_grid, cv=10, scoring='accuracy')
dt_clf3.fit(x3_train_tfidf, y3_train)

# Menampilkan parameter max_depth terbaik
print('best parameter : ', dt_clf3.best_params_)
# Out:
# best parameter :  {'max_depth': 29, 'splitter': 'random'}

# %%
# Menampilkan akurasi terbaik
print('accuracy : ', dt_clf3.best_score_)
# Out:
# accuracy :  0.7103424820596538

# %% [markdown]
# ### Decision Tree 70:30

# %%
# Melatih model klasifikasi dengan algoritma Decision Tree (CART)
dt_clf3 = DecisionTreeClassifier(criterion='gini', splitter='random', max_depth=29)
dt_clf3.fit(x3_train_tfidf, y3_train)

# Memprediksi label sentimen dengan data validasi
dt_predict3 = dt_clf3.predict(x3_test_tfidf)

# Menampilkan akurasi dari algoritma Decision Tree (CART) yang didapatkan
print("Decision Tree Accuracy Score:", round(accuracy_score(dt_predict3, y3_test) * 100, 4), '%')

# Menampilkan hasil evaluasi performa secara keseluruhan
print("Classification Report:")
print(classification_report(dt_predict3, y3_test, digits=4))
# Out:
# Decision Tree Accuracy Score: 70.0288 %
# Classification Report:
#               precision    recall  f1-score   support
#
#      negatif     0.7508    0.9225    0.8278       271
#       netral     0.4040    0.8994    0.5575       159
#      positif     0.9492    0.5499    0.6964       611
#
#     accuracy                         0.7003      1041
#    macro avg     0.7013    0.7906    0.6939      1041
# weighted avg     0.8142    0.7003    0.7094      1041

# %%
from sklearn.metrics import confusion_matrix

f , ax = plt.subplots(figsize = (6,5))
conf_mat = confusion_matrix(y3_test, dt_predict3)
class_label = ["Negatif", "Netral", "Positif"]
cm = pd.DataFrame(conf_mat, index=class_label, columns=class_label)
sns.heatmap(cm, annot = True,  fmt=".0f", ax=ax)
plt.title("Confusion Matrix Decision Tree 70:30", y=1, size=12)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
